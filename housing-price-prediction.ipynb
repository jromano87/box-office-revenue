# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# read the Houses dataset CSV file
housing_data = pd.read_csv("./real_estate.csv", sep=",")
housing_data.head()
# Out:
#       MLS            Location     Price  Bedrooms  Bathrooms  Size  \
# 0  132842       Arroyo Grande  795000.0         3          3  2371
# 1  134364         Paso Robles  399000.0         4          3  2818
# 2  135141         Paso Robles  545000.0         4          3  3032
# 3  135712           Morro Bay  909000.0         4          4  3540
# 4  136282  Santa Maria-Orcutt  109900.0         3          1  1249
#
#    Price/SQ.Ft      Status
# 0       335.30  Short Sale
# 1       141.59  Short Sale
# 2       179.75  Short Sale
# 3       256.78  Short Sale
# 4        87.99  Short Sale

# %%
# only get the Size and the Price features
# YOUR CODE HERE

# END CODE
print("Size shape:", Xs.shape)
print("Price shape:", Ys.shape)
dataset_size = Xs.shape[0]
print("Size:", dataset_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-50f944df5019> in <module>()
#       1 # only get the Size and the Price features
#       2
# ----> 3 Xs = housing_data[['Size']]
#       4 Ys = housing_data[['Price']]
#       5 print("Size shape:", Xs.shape)
#
# NameError: name 'housing_data' is not defined

# %%
# plot the price and the size
plt.plot(Xs, Ys, 'ro')

# %%
Xs = Xs.values.squeeze()
Ys = Ys.values.squeeze()

# %%
# Normalize the input features
# YOUR CODE HERE

# END CODE

# %%
# shuffle the dataset before separating test/train sets
p = np.random.permutation(len(Xs))
Xs = Xs[p]
Ys = Ys[p]

# %%
# separate train/test sets 
# Use 80% for training and 20% for testing
# YOUR CODE HERE

# END CODE

# %%
# plot the price and the size
fig = plt.figure()
fig.suptitle('Normalized housing Size/Price dataset', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.plot(Xs_train, Ys_train, 'ro')
ax.set_xlabel('Size')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
min_x = np.min(Xs_train)
max_x = np.max(Xs_train)

# %%
# Define the Linear model
# Initialize the weights using a normal (Gaussian) distribution with 0 mean and unit variance
W0 = np.random.normal(loc=0, scale=0.02) # Y intercept
W1 = np.asarray(np.random.normal(loc=0, scale=0.02)) # Slope of the line
W1 = W1.reshape((1))

# %%
def next_batch(Xs, Ys, batch_size=64):
    # Get a random sample of the Xs and Ys of size Xs
    # YOUR CODE HERE
    
    # END CODE 
    for i in range(0,Xs.shape[0],batch_size):
        # Extract the batch
        # YOUR CODE HERE 
        
        # END CODE 
        if x_batch.shape[0] < batch_size:
            continue
        yield np.reshape(x_batch, (batch_size,-1)), Ys[i:i+batch_size]

# %%
def eval_and_plot(W0, W1, min_x, max_x, id_):
    min_y = W0 + np.dot(W1, min_x)
    max_y = W0 + np.dot(W1, max_x)
    plt.plot(Xs_train, Ys_train, 'ro')
    plt.plot([min_x, max_x], [min_y, max_y], 'k-', lw=2)
    plt.show()

# %%
# defines the size of the step we want to perform in the direction of the gradient
step_size = 0.1

# set the pocket weights
W0_hat = np.inf
W1_hat = np.inf
best_hypothesis = np.inf

validation_err_list = []
training_err_list = []
batch_size = 96
total_epochs = 150

# %%
def mean_squared_error(Ys_batch, Y_pred):
    # YOUR CODE HERE
    pass
    # END CODE

# %%
for epoch in range(total_epochs):
    errors = []
    for X_batch, y_batch in next_batch(Xs_train, Ys_train, batch_size=batch_size):

        # linearly combine input and weights
        # YOUR CODE HERE
        
        # END CODE
    
        # calculate the SSE between predicted and true values
        train_err = mean_squared_error(y_batch, train_pred)
        errors.append(train_err)
        
        # calculate the gradients with respect to W0 and W1
        # YOUR CODE HERE
        
        # END CODE

        # update W0 and W1 in the opposite direction to the gradient
        # YOUR CODE HERE
        
        # END CODE
    
    if epoch % 20 == 0: 
        eval_and_plot(W0, W1, min_x, max_x, epoch+1)
    training_err_list.append(np.mean(errors))
    
    # test in the end of epoch
    val_pred = W0 + np.dot(np.reshape(Xs_test, (-1,1)), W1)
    val_err = mean_squared_error(Ys_test, val_pred)
    print("Epoch:", epoch, "Validation err:", val_err)
    validation_err_list.append(val_err)
    
    #epoch += 1
    if val_err < best_hypothesis:
        best_hypothesis = val_err
        W0_hat = W0
        W1_hat = W1
# Out:
# Epoch: 0 Generalization err: 0.0016316164059545692
# Epoch: 1 Generalization err: 0.0016207341779918274
# Epoch: 2 Generalization err: 0.0016220446458779245
# Epoch: 3 Generalization err: 0.0016193968888394855
# Epoch: 4 Generalization err: 0.0016244598283056918
# Epoch: 5 Generalization err: 0.0016405132424057553
# Epoch: 6 Generalization err: 0.0016361823608764532
# Epoch: 7 Generalization err: 0.0016310165304827438
# Epoch: 8 Generalization err: 0.0016540547143167183
# Epoch: 9 Generalization err: 0.0016284967183513906
# Epoch: 10 Generalization err: 0.0016563516583402726
# Epoch: 11 Generalization err: 0.0016450727003844586
# Epoch: 12 Generalization err: 0.0016757391766986304
# Epoch: 13 Generalization err: 0.0016743083747860845
# Epoch: 14 Generalization err: 0.0016490734199138487
# Epoch: 15 Generalization err: 0.001650025135906556
# Epoch: 16 Generalization err: 0.0016616471193418557
# Epoch: 17 Generalization err: 0.0016606112140663749
# Epoch: 18 Generalization err: 0.0016507362168369862
# Epoch: 19 Generalization err: 0.0016636248416329693
# Epoch: 20 Generalization err: 0.0016737777989013036
# Epoch: 21 Generalization err: 0.001652101599738266
# Epoch: 22 Generalization err: 0.0016666355364387273
# Epoch: 23 Generalization err: 0.001697293246957027
# Epoch: 24 Generalization err: 0.0016874806196769837
# Epoch: 25 Generalization err: 0.0017098547017527755
# Epoch: 26 Generalization err: 0.0017057050814022576
# Epoch: 27 Generalization err: 0.001686086465621466
# Epoch: 28 Generalization err: 0.0016962976445570614
# Epoch: 29 Generalization err: 0.0017032049695052598
# Epoch: 30 Generalization err: 0.0016815948411183237
# Epoch: 31 Generalization err: 0.0016899863507836733
# Epoch: 32 Generalization err: 0.0016926607492809573
# Epoch: 33 Generalization err: 0.0017049056586440283
# Epoch: 34 Generalization err: 0.0016729153545816506
# Epoch: 35 Generalization err: 0.0017225876146333878
# Epoch: 36 Generalization err: 0.001702393141179207
# Epoch: 37 Generalization err: 0.001689825701157688
# Epoch: 38 Generalization err: 0.0016913142650617178
# Epoch: 39 Generalization err: 0.0017062582715994645
# Epoch: 40 Generalization err: 0.0016944192504490926
# Epoch: 41 Generalization err: 0.0017137877330822622
# Epoch: 42 Generalization err: 0.0017081710897751247
# Epoch: 43 Generalization err: 0.0017030201037992476
# Epoch: 44 Generalization err: 0.001718498754649621
# Epoch: 45 Generalization err: 0.00174785277648016
# Epoch: 46 Generalization err: 0.0017098720027831666
# Epoch: 47 Generalization err: 0.0017043413136005963
# Epoch: 48 Generalization err: 0.0017163226268033043
# Epoch: 49 Generalization err: 0.00171349481371728
# Epoch: 50 Generalization err: 0.0017177119756933898
# Epoch: 51 Generalization err: 0.0017247055265759593
# Epoch: 52 Generalization err: 0.0017002365773263026
# Epoch: 53 Generalization err: 0.0017031532020396504
# Epoch: 54 Generalization err: 0.0017141744498712214
# Epoch: 55 Generalization err: 0.001740706665346643
# Epoch: 56 Generalization err: 0.0017189596181199024
# Epoch: 57 Generalization err: 0.0017570905246246159
# Epoch: 58 Generalization err: 0.0017294892595327586
# Epoch: 59 Generalization err: 0.0017212955015660338
# Epoch: 60 Generalization err: 0.0017252475283677934
# Epoch: 61 Generalization err: 0.00173247106519503
# Epoch: 62 Generalization err: 0.0017287907711763084
# Epoch: 63 Generalization err: 0.001745443905996976
# Epoch: 64 Generalization err: 0.0017170625652996089
# Epoch: 65 Generalization err: 0.0017308098351182038
# Epoch: 66 Generalization err: 0.0017509470519031076
# Epoch: 67 Generalization err: 0.0017444640411610197
# Epoch: 68 Generalization err: 0.0017602285063196943
# Epoch: 69 Generalization err: 0.0017590210831341907
# Epoch: 70 Generalization err: 0.001721796072642665
# Epoch: 71 Generalization err: 0.0017316547697863417
# Epoch: 72 Generalization err: 0.001753087321891879
# Epoch: 73 Generalization err: 0.0017392111039791047
# Epoch: 74 Generalization err: 0.0017505160528635873
# Epoch: 75 Generalization err: 0.001747192637259163
# Epoch: 76 Generalization err: 0.0017648568455015828
# Epoch: 77 Generalization err: 0.0017893023972889019
# Epoch: 78 Generalization err: 0.0017596183448839826
# Epoch: 79 Generalization err: 0.0017644410997742573
# Epoch: 80 Generalization err: 0.0017799204879790926
# Epoch: 81 Generalization err: 0.0017536010236637587
# Epoch: 82 Generalization err: 0.001772348102155693
# Epoch: 83 Generalization err: 0.001743878952492937
# Epoch: 84 Generalization err: 0.0017532285181621643
# Epoch: 85 Generalization err: 0.0017470510835504232
# Epoch: 86 Generalization err: 0.0017561890376463012
# Epoch: 87 Generalization err: 0.0017581037178771507
# Epoch: 88 Generalization err: 0.0017679805220309657
# Epoch: 89 Generalization err: 0.0017734678923549217
# Epoch: 90 Generalization err: 0.0017780499988090646
# Epoch: 91 Generalization err: 0.0017948652604876103
# Epoch: 92 Generalization err: 0.0017658657494848764
# Epoch: 93 Generalization err: 0.0017483736942939625
# Epoch: 94 Generalization err: 0.001786990745422298
# Epoch: 95 Generalization err: 0.0017976479582050712
# Epoch: 96 Generalization err: 0.0017837929858953603
# Epoch: 97 Generalization err: 0.0017660147761393281
# Epoch: 98 Generalization err: 0.001757936544397709
# Epoch: 99 Generalization err: 0.0017793251257406772
# Epoch: 100 Generalization err: 0.00177679980910865
# Epoch: 101 Generalization err: 0.0017561203775708439
# Epoch: 102 Generalization err: 0.0017664686488177697
# Epoch: 103 Generalization err: 0.0017712247923622527
# Epoch: 104 Generalization err: 0.0017785467011414157
# Epoch: 105 Generalization err: 0.001785544241757565
# Epoch: 106 Generalization err: 0.0017647910926134355
# Epoch: 107 Generalization err: 0.00175410676193361
# Epoch: 108 Generalization err: 0.001775827209700416
# Epoch: 109 Generalization err: 0.0017695548566684868
# Epoch: 110 Generalization err: 0.0017980340493409324
# Epoch: 111 Generalization err: 0.001801257069693249
# Epoch: 112 Generalization err: 0.0017985336198420626
# Epoch: 113 Generalization err: 0.0017725689921813394
# Epoch: 114 Generalization err: 0.001793791878655963
# Epoch: 115 Generalization err: 0.0017893712815226193
# Epoch: 116 Generalization err: 0.0017853338320064555
# Epoch: 117 Generalization err: 0.0017934123238918195
# Epoch: 118 Generalization err: 0.001757974528732672
# Epoch: 119 Generalization err: 0.0017602431751395139
# Epoch: 120 Generalization err: 0.0017662252206968418
# Epoch: 121 Generalization err: 0.0017750323639075854
# Epoch: 122 Generalization err: 0.001803656606701011
# Epoch: 123 Generalization err: 0.0017948685087270794
# Epoch: 124 Generalization err: 0.001780501895709419
# Epoch: 125 Generalization err: 0.0017714219286494338
# Epoch: 126 Generalization err: 0.0017675494804421368
# Epoch: 127 Generalization err: 0.0017823666185070618
# Epoch: 128 Generalization err: 0.0017939391561392108
# Epoch: 129 Generalization err: 0.0017817677194082156
# Epoch: 130 Generalization err: 0.0018132930680125965
# Epoch: 131 Generalization err: 0.0018079710646382915
# Epoch: 132 Generalization err: 0.0018001184877820499
# Epoch: 133 Generalization err: 0.0017973346073900849
# Epoch: 134 Generalization err: 0.0018212869804612318
# Epoch: 135 Generalization err: 0.0018081793840849711
# Epoch: 136 Generalization err: 0.001775328431637302
# Epoch: 137 Generalization err: 0.0017919956318280092
# Epoch: 138 Generalization err: 0.0017963319100207946
# Epoch: 139 Generalization err: 0.0018091161133967728
# Epoch: 140 Generalization err: 0.0017798466925179567
# Epoch: 141 Generalization err: 0.0018104426174801588
# Epoch: 142 Generalization err: 0.001785900493217586
# Epoch: 143 Generalization err: 0.0018044969226045696
# Epoch: 144 Generalization err: 0.001787460808535486
# Epoch: 145 Generalization err: 0.0018049588817189573
# Epoch: 146 Generalization err: 0.0017875253835051986
# Epoch: 147 Generalization err: 0.0017963410781812778
# Epoch: 148 Generalization err: 0.0017985895513753496
# Epoch: 149 Generalization err: 0.001790216396762152

# %%
# plot the price and the size
plt.plot(validation_err_list, label="validation")
plt.plot(training_err_list, label="training")
plt.xlabel('Epoch')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')
